# %%
import numpy as np
import time 
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.6.0

# %%
ARUCO_DICT = {
	"DICT_4X4_50": cv2.aruco.DICT_4X4_50,
	"DICT_4X4_100": cv2.aruco.DICT_4X4_100,
	"DICT_4X4_250": cv2.aruco.DICT_4X4_250,
	"DICT_4X4_1000": cv2.aruco.DICT_4X4_1000,
	"DICT_5X5_50": cv2.aruco.DICT_5X5_50,
	"DICT_5X5_100": cv2.aruco.DICT_5X5_100,
	"DICT_5X5_250": cv2.aruco.DICT_5X5_250,
	"DICT_5X5_1000": cv2.aruco.DICT_5X5_1000,
	"DICT_6X6_50": cv2.aruco.DICT_6X6_50,
	"DICT_6X6_100": cv2.aruco.DICT_6X6_100,
	"DICT_6X6_250": cv2.aruco.DICT_6X6_250,
	"DICT_6X6_1000": cv2.aruco.DICT_6X6_1000,
	"DICT_7X7_50": cv2.aruco.DICT_7X7_50,
	"DICT_7X7_100": cv2.aruco.DICT_7X7_100,
	"DICT_7X7_250": cv2.aruco.DICT_7X7_250,
	"DICT_7X7_1000": cv2.aruco.DICT_7X7_1000,
	"DICT_ARUCO_ORIGINAL": cv2.aruco.DICT_ARUCO_ORIGINAL,
	"DICT_APRILTAG_16h5": cv2.aruco.DICT_APRILTAG_16h5,
	"DICT_APRILTAG_25h9": cv2.aruco.DICT_APRILTAG_25h9,
	"DICT_APRILTAG_36h10": cv2.aruco.DICT_APRILTAG_36h10,
	"DICT_APRILTAG_36h11": cv2.aruco.DICT_APRILTAG_36h11
}

# %%
def unique_recog(id):
    arr=np.array(id)
    arr =arr[arr !=np.array(None)]
    for i in arr:
        if i not in uniques:
            uniques.append(i)
            print ("markers detected so far are :",uniques)
        else:
            continue

# %%
def aruco_display(corners,ids, rejected,image):
    if len(corners)>0:
        ids=ids.flatten()
        for(markerCorner,markerID) in zip(corners,ids):
            corners=markerCorner.reshape((4,2))
            (topleft,topright,bottomright,bottomleft)=corners
            
            topright=(int(topright[0]),int(topright[1]))
            bottomright=(int(bottomright[0]),int(bottomright[1]))
            bottomleft=(int(bottomleft[0]),int(bottomleft[1]))
            topleft=(int(topleft[0]),int(topleft[1]))
            
            cv2.line(image,topleft,topright,(0,255,0),2 )
            cv2.line(image,topright,topright,(0,255,0),2 )
            cv2.line(image,bottomleft,topright,(0,255,0),2 )
            cv2.line(image,bottomright,topright,(0,255,0),2 )
            
            cx=int((topleft[0]+bottomright[0])/2.0)
            cy=int((topleft[1]+bottomright[1])/2.0)
            
            cv2.circle(image, (cx,cy) ,4,(0,0,255),-1)
            
            
            cv2.putText(image,str(markerID),(topleft[0],topleft[1]-10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2)
            
    return image

# %%
aruco_type="DICT_4X4_100"
arucoDict=cv2.aruco.Dictionary_get(ARUCO_DICT[aruco_type])
arucoParams=cv2.aruco.DetectorParameters_create()


uniques=[]

cap=cv2.VideoCapture(0)

cap.set(cv2.CAP_PROP_FRAME_WIDTH,1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,720)
while cap.isOpened(): 
    ret,img=cap.read()
    h, w, _=img.shape
    
    width=1000
    height=int(width*(h/w))
    
    img=cv2.resize(img,(width,height),interpolation=cv2.INTER_CUBIC)
    
    corners,ids,rejected=cv2.aruco.detectMarkers(img,arucoDict,parameters=arucoParams)

    detected_markers=aruco_display(corners,ids,rejected,img)
    print(corners,ids)
    
    cv2.imshow("image", detected_markers)
    unique_recog(ids)
    
    key=cv2.waitKey(1)& 0xFF
    
    if key==ord("q"):
        break
        
        
cv2.destroyAllWindows()
cap.release()
# Out:
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[123., 330.],
#         [161., 331.],
#         [157., 368.],
#         [119., 366.]]], dtype=float32),) [[1]]
# markers detected so far are : [1]
# (array([[[144., 329.],
#         [182., 330.],
#         [179., 368.],
#         [138., 367.]]], dtype=float32),) [[1]]
# (array([[[149., 326.],
#         [190., 327.],
#         [186., 365.],
#         [146., 364.]]], dtype=float32),) [[1]]
# (array([[[157., 323.],
#         [196., 325.],
#         [193., 363.],
#         [152., 362.]]], dtype=float32),) [[1]]
# (array([[[161., 323.],
#         [201., 325.],
#         [198., 363.],
#         [157., 361.]]], dtype=float32),) [[1]]
# (array([[[165., 323.],
#         [205., 326.],
#         [202., 364.],
#         [162., 362.]]], dtype=float32),) [[1]]
# (array([[[168., 323.],
#         [207., 325.],
#         [204., 364.],
#         [165., 362.]]], dtype=float32),) [[1]]
# (array([[[170., 322.],
#         [209., 324.],
#         [206., 363.],
#         [166., 361.]]], dtype=float32),) [[1]]
# (array([[[171., 322.],
#         [211., 324.],
#         [208., 363.],
#         [168., 361.]]], dtype=float32),) [[1]]
# (array([[[173., 323.],
#         [212., 326.],
#         [209., 365.],
#         [169., 362.]]], dtype=float32),) [[1]]
# (array([[[173., 327.],
#         [212., 330.],
#         [209., 368.],
#         [169., 366.]]], dtype=float32),) [[1]]
# (array([[[173., 331.],
#         [211., 334.],
#         [209., 372.],
#         [168., 370.]]], dtype=float32),) [[1]]
# (array([[[171., 335.],
#         [210., 337.],
#         [207., 376.],
#         [167., 374.]]], dtype=float32),) [[1]]
# (array([[[169., 337.],
#         [208., 340.],
#         [205., 379.],
#         [165., 377.]]], dtype=float32),) [[1]]
# (array([[[167., 339.],
#         [207., 342.],
#         [205., 380.],
#         [164., 379.]]], dtype=float32),) [[1]]
# (array([[[167., 341.],
#         [207., 343.],
#         [205., 382.],
#         [164., 380.]]], dtype=float32),) [[1]]
# (array([[[168., 343.],
#         [209., 346.],
#         [207., 384.],
#         [166., 382.]]], dtype=float32),) [[1]]
# (array([[[172., 345.],
#         [212., 348.],
#         [210., 386.],
#         [169., 384.]]], dtype=float32),) [[1]]
# (array([[[175., 348.],
#         [216., 350.],
#         [213., 388.],
#         [173., 385.]]], dtype=float32),) [[1]]
# (array([[[181., 348.],
#         [220., 350.],
#         [217., 388.],
#         [178., 386.]]], dtype=float32),) [[1]]
# (array([[[187., 348.],
#         [225., 350.],
#         [223., 386.],
#         [184., 385.]]], dtype=float32),) [[1]]
# (array([[[194., 346.],
#         [231., 348.],
#         [228., 383.],
#         [190., 382.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[300., 362.],
#         [325., 364.],
#         [323., 388.],
#         [299., 387.]]], dtype=float32),) [[1]]
# (array([[[300., 365.],
#         [325., 367.],
#         [324., 391.],
#         [299., 390.]]], dtype=float32),) [[1]]
# (array([[[301., 369.],
#         [325., 372.],
#         [322., 396.],
#         [299., 395.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# (array([[[298., 388.],
#         [322., 389.],
#         [320., 414.],
#         [295., 412.]]], dtype=float32),) [[1]]
# (array([[[295., 392.],
#         [320., 393.],
#         [317., 418.],
#         [293., 417.]]], dtype=float32),) [[1]]
# (array([[[292., 396.],
#         [317., 396.],
#         [315., 422.],
#         [290., 422.]]], dtype=float32),) [[1]]
# (array([[[290., 400.],
#         [315., 400.],
#         [312., 427.],
#         [287., 426.]]], dtype=float32),) [[1]]
# () None
# () None
# (array([[[285., 415.],
#         [311., 416.],
#         [309., 442.],
#         [283., 441.]]], dtype=float32),) [[1]]
# (array([[[284., 417.],
#         [310., 418.],
#         [309., 443.],
#         [283., 443.]]], dtype=float32),) [[1]]
# (array([[[284., 417.],
#         [310., 417.],
#         [309., 443.],
#         [283., 443.]]], dtype=float32),) [[1]]
# (array([[[284., 416.],
#         [310., 417.],
#         [309., 442.],
#         [283., 442.]]], dtype=float32),) [[1]]
# (array([[[284., 416.],
#         [310., 417.],
#         [308., 443.],
#         [283., 443.]]], dtype=float32),) [[1]]
# (array([[[284., 418.],
#         [310., 418.],
#         [308., 444.],
#         [283., 444.]]], dtype=float32),) [[1]]
# (array([[[284., 419.],
#         [310., 420.],
#         [308., 445.],
#         [283., 445.]]], dtype=float32),) [[1]]
# (array([[[283., 420.],
#         [309., 420.],
#         [308., 445.],
#         [282., 445.]]], dtype=float32),) [[1]]
# (array([[[282., 420.],
#         [308., 419.],
#         [308., 444.],
#         [282., 445.]]], dtype=float32),) [[1]]
# (array([[[282., 418.],
#         [307., 418.],
#         [306., 443.],
#         [281., 443.]]], dtype=float32),) [[1]]
# (array([[[280., 417.],
#         [306., 417.],
#         [305., 442.],
#         [279., 441.]]], dtype=float32),) [[1]]
# (array([[[279., 417.],
#         [303., 417.],
#         [302., 442.],
#         [278., 442.]]], dtype=float32),) [[1]]
# (array([[[275., 418.],
#         [300., 417.],
#         [300., 442.],
#         [275., 442.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[342., 328.],
#         [346., 314.],
#         [385., 313.],
#         [382., 329.]]], dtype=float32),) [[74]]
# markers detected so far are : [1, 74]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[  7., 427.],
#         [ 34., 431.],
#         [ 31., 460.],
#         [  3., 458.]]], dtype=float32),) [[1]]
# (array([[[  9., 430.],
#         [ 36., 434.],
#         [ 32., 463.],
#         [  4., 460.]]], dtype=float32),) [[1]]
# (array([[[ 11., 433.],
#         [ 39., 435.],
#         [ 36., 465.],
#         [  7., 463.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# (array([[[ 52., 439.],
#         [ 84., 430.],
#         [ 93., 457.],
#         [ 60., 467.]]], dtype=float32),) [[1]]
# (array([[[ 54., 439.],
#         [ 88., 432.],
#         [ 93., 459.],
#         [ 60., 467.]]], dtype=float32),) [[1]]
# (array([[[ 56., 438.],
#         [ 88., 432.],
#         [ 94., 460.],
#         [ 61., 468.]]], dtype=float32),) [[1]]
# (array([[[ 57., 439.],
#         [ 91., 433.],
#         [ 94., 461.],
#         [ 60., 466.]]], dtype=float32),) [[1]]
# (array([[[ 60., 439.],
#         [ 93., 432.],
#         [ 97., 461.],
#         [ 63., 467.]]], dtype=float32),) [[1]]
# (array([[[ 62., 439.],
#         [ 96., 432.],
#         [100., 460.],
#         [ 67., 467.]]], dtype=float32),) [[1]]
# (array([[[ 65., 439.],
#         [ 97., 432.],
#         [102., 460.],
#         [ 68., 467.]]], dtype=float32),) [[1]]
# (array([[[ 68., 439.],
#         [100., 433.],
#         [104., 461.],
#         [ 72., 468.]]], dtype=float32),) [[1]]
# (array([[[ 70., 439.],
#         [102., 432.],
#         [107., 460.],
#         [ 74., 467.]]], dtype=float32),) [[1]]
# (array([[[ 72., 438.],
#         [105., 431.],
#         [109., 459.],
#         [ 77., 466.]]], dtype=float32),) [[1]]
# (array([[[ 75., 437.],
#         [106., 430.],
#         [111., 458.],
#         [ 79., 465.]]], dtype=float32),) [[1]]
# (array([[[ 76., 437.],
#         [108., 430.],
#         [113., 457.],
#         [ 81., 465.]]], dtype=float32),) [[1]]
# (array([[[ 78., 437.],
#         [110., 430.],
#         [115., 457.],
#         [ 82., 464.]]], dtype=float32),) [[1]]
# (array([[[ 80., 436.],
#         [113., 429.],
#         [117., 457.],
#         [ 85., 464.]]], dtype=float32),) [[1]]
# (array([[[ 84., 435.],
#         [115., 429.],
#         [120., 456.],
#         [ 87., 464.]]], dtype=float32),) [[1]]
# (array([[[ 86., 434.],
#         [118., 428.],
#         [123., 455.],
#         [ 90., 463.]]], dtype=float32),) [[1]]
# (array([[[ 89., 434.],
#         [120., 427.],
#         [125., 455.],
#         [ 93., 462.]]], dtype=float32),) [[1]]
# (array([[[ 92., 433.],
#         [123., 427.],
#         [129., 454.],
#         [ 96., 462.]]], dtype=float32),) [[1]]
# (array([[[ 95., 433.],
#         [127., 426.],
#         [132., 455.],
#         [101., 462.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[797., 427.],
#         [823., 429.],
#         [820., 466.],
#         [792., 464.]]], dtype=float32),) [[1]]
# (array([[[799., 422.],
#         [825., 423.],
#         [824., 460.],
#         [797., 458.]]], dtype=float32),) [[1]]
# (array([[[800., 418.],
#         [827., 421.],
#         [827., 456.],
#         [799., 455.]]], dtype=float32),) [[1]]
# (array([[[800., 417.],
#         [827., 418.],
#         [827., 455.],
#         [800., 454.]]], dtype=float32),) [[1]]
# (array([[[800., 417.],
#         [827., 419.],
#         [827., 455.],
#         [800., 454.]]], dtype=float32),) [[1]]
# (array([[[798., 418.],
#         [826., 420.],
#         [827., 455.],
#         [799., 454.]]], dtype=float32),) [[1]]
# (array([[[797., 417.],
#         [825., 420.],
#         [824., 456.],
#         [796., 453.]]], dtype=float32),) [[1]]
# (array([[[793., 416.],
#         [823., 420.],
#         [822., 455.],
#         [793., 453.]]], dtype=float32),) [[1]]
# (array([[[790., 415.],
#         [820., 419.],
#         [819., 455.],
#         [789., 451.]]], dtype=float32),) [[1]]
# (array([[[787., 415.],
#         [818., 419.],
#         [815., 455.],
#         [786., 451.]]], dtype=float32),) [[1]]
# (array([[[786., 415.],
#         [816., 420.],
#         [814., 456.],
#         [783., 452.]]], dtype=float32),) [[1]]
# (array([[[784., 418.],
#         [815., 422.],
#         [812., 458.],
#         [781., 454.]]], dtype=float32),) [[1]]
# (array([[[783., 421.],
#         [814., 425.],
#         [811., 462.],
#         [780., 458.]]], dtype=float32),) [[1]]
# (array([[[782., 424.],
#         [814., 429.],
#         [810., 465.],
#         [778., 462.]]], dtype=float32),) [[1]]
# (array([[[781., 427.],
#         [813., 432.],
#         [808., 469.],
#         [776., 464.]]], dtype=float32),) [[1]]
# (array([[[778., 431.],
#         [811., 435.],
#         [807., 472.],
#         [774., 468.]]], dtype=float32),) [[1]]
# (array([[[777., 433.],
#         [810., 438.],
#         [805., 474.],
#         [772., 471.]]], dtype=float32),) [[1]]
# (array([[[774., 436.],
#         [807., 440.],
#         [802., 478.],
#         [769., 474.]]], dtype=float32),) [[1]]
# (array([[[771., 438.],
#         [805., 442.],
#         [801., 480.],
#         [767., 476.]]], dtype=float32),) [[1]]
# (array([[[769., 440.],
#         [803., 444.],
#         [798., 482.],
#         [764., 478.]]], dtype=float32),) [[1]]
# (array([[[767., 441.],
#         [800., 444.],
#         [796., 483.],
#         [763., 479.]]], dtype=float32),) [[1]]
# (array([[[765., 442.],
#         [799., 446.],
#         [795., 483.],
#         [761., 480.]]], dtype=float32),) [[1]]
# (array([[[764., 441.],
#         [797., 445.],
#         [793., 483.],
#         [759., 479.]]], dtype=float32),) [[1]]
# (array([[[763., 440.],
#         [796., 444.],
#         [792., 482.],
#         [759., 479.]]], dtype=float32),) [[1]]
# (array([[[762., 439.],
#         [795., 442.],
#         [792., 480.],
#         [759., 478.]]], dtype=float32),) [[1]]
# (array([[[762., 438.],
#         [796., 440.],
#         [793., 478.],
#         [760., 476.]]], dtype=float32),) [[1]]
# (array([[[764., 435.],
#         [798., 437.],
#         [796., 475.],
#         [762., 474.]]], dtype=float32),) [[1]]
# (array([[[768., 432.],
#         [801., 434.],
#         [799., 472.],
#         [765., 472.]]], dtype=float32),) [[1]]
# (array([[[770., 429.],
#         [805., 431.],
#         [803., 469.],
#         [769., 468.]]], dtype=float32),) [[1]]
# (array([[[775., 425.],
#         [810., 425.],
#         [810., 465.],
#         [774., 466.]]], dtype=float32),) [[1]]
# (array([[[780., 422.],
#         [816., 421.],
#         [816., 463.],
#         [780., 463.]]], dtype=float32),) [[1]]
# (array([[[786., 419.],
#         [824., 419.],
#         [823., 461.],
#         [786., 460.]]], dtype=float32),) [[1]]
# (array([[[794., 415.],
#         [832., 415.],
#         [833., 459.],
#         [794., 459.]]], dtype=float32),) [[1]]
# () None
# (array([[[808., 411.],
#         [847., 413.],
#         [849., 457.],
#         [808., 457.]]], dtype=float32),) [[1]]
# (array([[[813., 409.],
#         [854., 408.],
#         [857., 454.],
#         [815., 454.]]], dtype=float32),) [[1]]
# (array([[[823., 402.],
#         [861., 403.],
#         [861., 451.],
#         [821., 451.]]], dtype=float32),) [[1]]
# (array([[[830., 395.],
#         [868., 397.],
#         [868., 445.],
#         [827., 445.]]], dtype=float32),) [[1]]
# (array([[[833., 389.],
#         [874., 389.],
#         [876., 437.],
#         [833., 438.]]], dtype=float32),) [[1]]
# (array([[[837., 382.],
#         [881., 380.],
#         [881., 431.],
#         [839., 432.]]], dtype=float32),) [[1]]
# (array([[[843., 374.],
#         [886., 374.],
#         [887., 425.],
#         [844., 426.]]], dtype=float32),) [[1]]
# (array([[[847., 367.],
#         [892., 368.],
#         [893., 421.],
#         [849., 422.]]], dtype=float32),) [[1]]
# (array([[[852., 361.],
#         [897., 363.],
#         [900., 418.],
#         [852., 417.]]], dtype=float32),) [[1]]
# (array([[[854., 359.],
#         [902., 361.],
#         [905., 419.],
#         [856., 418.]]], dtype=float32),) [[1]]
# (array([[[857., 361.],
#         [906., 364.],
#         [909., 423.],
#         [860., 421.]]], dtype=float32),) [[1]]
# (array([[[862., 366.],
#         [913., 371.],
#         [915., 430.],
#         [865., 430.]]], dtype=float32),) [[1]]
# (array([[[865., 372.],
#         [920., 379.],
#         [924., 440.],
#         [871., 439.]]], dtype=float32),) [[1]]
# (array([[[873., 381.],
#         [928., 384.],
#         [931., 452.],
#         [881., 452.]]], dtype=float32),) [[1]]
# () None
# () None
# (array([[[907., 418.],
#         [972., 423.],
#         [977., 498.],
#         [919., 502.]]], dtype=float32),) [[1]]
# (array([[[918., 434.],
#         [980., 431.],
#         [996., 515.],
#         [930., 519.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[882., 186.],
#         [894., 178.],
#         [899., 177.],
#         [882., 190.]]], dtype=float32),) [[17]]
# markers detected so far are : [1, 74, 17]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[141., 409.],
#         [233., 409.],
#         [231., 495.],
#         [134., 500.]]], dtype=float32),) [[1]]
# (array([[[139., 402.],
#         [232., 400.],
#         [231., 488.],
#         [133., 493.]]], dtype=float32),) [[1]]
# (array([[[135., 399.],
#         [230., 397.],
#         [229., 487.],
#         [131., 493.]]], dtype=float32),) [[1]]
# (array([[[131., 401.],
#         [228., 398.],
#         [227., 489.],
#         [129., 495.]]], dtype=float32),) [[1]]
# (array([[[129., 404.],
#         [226., 400.],
#         [228., 491.],
#         [130., 499.]]], dtype=float32),) [[1]]
# (array([[[130., 409.],
#         [226., 406.],
#         [227., 495.],
#         [130., 504.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# (array([[[139., 448.],
#         [234., 443.],
#         [238., 528.],
#         [144., 537.]]], dtype=float32),) [[1]]
# (array([[[143., 450.],
#         [237., 446.],
#         [240., 531.],
#         [148., 539.]]], dtype=float32),) [[1]]
# (array([[[146., 455.],
#         [239., 449.],
#         [243., 533.],
#         [152., 541.]]], dtype=float32),) [[1]]
# (array([[[149., 459.],
#         [242., 452.],
#         [246., 534.],
#         [155., 543.]]], dtype=float32),) [[1]]
# (array([[[150., 463.],
#         [241., 456.],
#         [245., 539.],
#         [155., 547.]]], dtype=float32),) [[1]]
# (array([[[150., 467.],
#         [240., 463.],
#         [243., 544.],
#         [152., 553.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[135., 481.],
#         [228., 469.],
#         [233., 543.],
#         [142., 558.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[107., 331.],
#         [179., 334.],
#         [177., 392.],
#         [107., 392.]]], dtype=float32),) [[1]]
# (array([[[ 98., 338.],
#         [170., 336.],
#         [165., 393.],
#         [ 97., 396.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[ 22., 479.],
#         [108., 487.],
#         [ 89., 551.],
#         [  4., 547.]]], dtype=float32),) [[1]]
# (array([[[ 29., 474.],
#         [112., 482.],
#         [ 95., 546.],
#         [ 10., 540.]]], dtype=float32),) [[1]]
# (array([[[ 37., 468.],
#         [118., 478.],
#         [100., 541.],
#         [ 17., 534.]]], dtype=float32),) [[1]]
# (array([[[ 44., 463.],
#         [125., 474.],
#         [105., 536.],
#         [ 24., 530.]]], dtype=float32),) [[1]]
# (array([[[ 51., 459.],
#         [132., 468.],
#         [113., 531.],
#         [ 31., 523.]]], dtype=float32),) [[1]]
# (array([[[ 62., 452.],
#         [139., 463.],
#         [118., 527.],
#         [ 39., 518.]]], dtype=float32),) [[1]]
# (array([[[ 66., 448.],
#         [146., 461.],
#         [124., 523.],
#         [ 46., 513.]]], dtype=float32),) [[1]]
# (array([[[ 74., 444.],
#         [151., 457.],
#         [130., 521.],
#         [ 50., 510.]]], dtype=float32),) [[1]]
# (array([[[ 82., 442.],
#         [158., 456.],
#         [136., 518.],
#         [ 59., 508.]]], dtype=float32),) [[1]]
# (array([[[ 88., 440.],
#         [163., 455.],
#         [142., 518.],
#         [ 64., 506.]]], dtype=float32),) [[1]]
# (array([[[ 93., 439.],
#         [168., 453.],
#         [147., 516.],
#         [ 70., 505.]]], dtype=float32),) [[1]]
# (array([[[ 98., 437.],
#         [172., 452.],
#         [149., 515.],
#         [ 75., 504.]]], dtype=float32),) [[1]]
# (array([[[102., 435.],
#         [175., 450.],
#         [153., 512.],
#         [ 79., 501.]]], dtype=float32),) [[1]]
# (array([[[105., 432.],
#         [177., 447.],
#         [156., 509.],
#         [ 82., 497.]]], dtype=float32),) [[1]]
# (array([[[106., 429.],
#         [179., 444.],
#         [157., 506.],
#         [ 84., 494.]]], dtype=float32),) [[1]]
# (array([[[109., 425.],
#         [181., 440.],
#         [158., 503.],
#         [ 85., 490.]]], dtype=float32),) [[1]]
# (array([[[110., 423.],
#         [182., 439.],
#         [160., 501.],
#         [ 87., 489.]]], dtype=float32),) [[1]]
# (array([[[112., 421.],
#         [183., 437.],
#         [161., 500.],
#         [ 88., 487.]]], dtype=float32),) [[1]]
# (array([[[113., 420.],
#         [184., 437.],
#         [161., 499.],
#         [ 89., 485.]]], dtype=float32),) [[1]]
# (array([[[113., 419.],
#         [183., 435.],
#         [161., 498.],
#         [ 89., 485.]]], dtype=float32),) [[1]]
# (array([[[113., 418.],
#         [184., 434.],
#         [162., 496.],
#         [ 89., 483.]]], dtype=float32),) [[1]]
# (array([[[112., 417.],
#         [185., 433.],
#         [161., 495.],
#         [ 89., 481.]]], dtype=float32),) [[1]]
# (array([[[114., 415.],
#         [185., 432.],
#         [161., 495.],
#         [ 90., 480.]]], dtype=float32),) [[1]]
# (array([[[117., 415.],
#         [188., 432.],
#         [164., 494.],
#         [ 91., 479.]]], dtype=float32),) [[1]]
# (array([[[120., 413.],
#         [190., 431.],
#         [167., 492.],
#         [ 95., 477.]]], dtype=float32),) [[1]]
# (array([[[123., 411.],
#         [192., 429.],
#         [168., 492.],
#         [ 97., 476.]]], dtype=float32),) [[1]]
# (array([[[123., 411.],
#         [193., 427.],
#         [170., 490.],
#         [100., 476.]]], dtype=float32),) [[1]]
# (array([[[120., 411.],
#         [190., 425.],
#         [172., 487.],
#         [100., 477.]]], dtype=float32),) [[1]]
# (array([[[118., 411.],
#         [188., 420.],
#         [174., 483.],
#         [103., 478.]]], dtype=float32),) [[1]]
# (array([[[113., 411.],
#         [182., 415.],
#         [175., 478.],
#         [104., 479.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# (array([[[ 81., 369.],
#         [150., 365.],
#         [153., 423.],
#         [ 86., 432.]]], dtype=float32),) [[1]]
# (array([[[ 79., 365.],
#         [148., 359.],
#         [153., 418.],
#         [ 85., 428.]]], dtype=float32),) [[1]]
# (array([[[ 79., 361.],
#         [149., 356.],
#         [153., 417.],
#         [ 85., 425.]]], dtype=float32),) [[1]]
# (array([[[ 81., 360.],
#         [149., 355.],
#         [154., 416.],
#         [ 86., 424.]]], dtype=float32),) [[1]]
# (array([[[ 84., 361.],
#         [153., 356.],
#         [158., 417.],
#         [ 89., 424.]]], dtype=float32),) [[1]]
# (array([[[ 88., 364.],
#         [157., 359.],
#         [160., 419.],
#         [ 93., 426.]]], dtype=float32),) [[1]]
# (array([[[ 93., 366.],
#         [159., 361.],
#         [164., 422.],
#         [ 97., 429.]]], dtype=float32),) [[1]]
# (array([[[ 96., 369.],
#         [163., 364.],
#         [168., 425.],
#         [100., 432.]]], dtype=float32),) [[1]]
# (array([[[ 99., 372.],
#         [166., 367.],
#         [171., 428.],
#         [103., 435.]]], dtype=float32),) [[1]]
# (array([[[101., 375.],
#         [170., 370.],
#         [172., 431.],
#         [105., 439.]]], dtype=float32),) [[1]]
# (array([[[102., 377.],
#         [171., 373.],
#         [173., 434.],
#         [106., 441.]]], dtype=float32),) [[1]]
# (array([[[103., 378.],
#         [171., 374.],
#         [174., 435.],
#         [105., 443.]]], dtype=float32),) [[1]]
# (array([[[102., 379.],
#         [171., 375.],
#         [173., 437.],
#         [105., 444.]]], dtype=float32),) [[1]]
# (array([[[102., 379.],
#         [171., 375.],
#         [172., 437.],
#         [104., 444.]]], dtype=float32),) [[1]]
# (array([[[102., 379.],
#         [171., 375.],
#         [173., 437.],
#         [104., 444.]]], dtype=float32),) [[1]]
# (array([[[102., 381.],
#         [171., 376.],
#         [174., 437.],
#         [105., 445.]]], dtype=float32),) [[1]]
# (array([[[105., 382.],
#         [173., 379.],
#         [175., 439.],
#         [108., 448.]]], dtype=float32),) [[1]]
# (array([[[107., 388.],
#         [176., 385.],
#         [179., 445.],
#         [109., 450.]]], dtype=float32),) [[1]]
# (array([[[113., 393.],
#         [179., 391.],
#         [182., 451.],
#         [115., 458.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[514., 434.],
#         [562., 433.],
#         [552., 493.],
#         [504., 498.]]], dtype=float32),) [[1]]
# (array([[[522., 432.],
#         [570., 430.],
#         [562., 489.],
#         [515., 495.]]], dtype=float32),) [[1]]
# (array([[[530., 428.],
#         [578., 426.],
#         [566., 486.],
#         [520., 491.]]], dtype=float32),) [[1]]
# (array([[[533., 423.],
#         [580., 420.],
#         [569., 481.],
#         [523., 482.]]], dtype=float32),) [[1]]
# (array([[[534., 414.],
#         [580., 414.],
#         [570., 473.],
#         [525., 477.]]], dtype=float32),) [[1]]
# (array([[[533., 409.],
#         [580., 411.],
#         [568., 468.],
#         [523., 467.]]], dtype=float32),) [[1]]
# (array([[[532., 402.],
#         [578., 406.],
#         [566., 462.],
#         [520., 460.]]], dtype=float32),) [[1]]
# (array([[[529., 397.],
#         [577., 401.],
#         [564., 457.],
#         [518., 455.]]], dtype=float32),) [[1]]
# (array([[[528., 392.],
#         [575., 395.],
#         [563., 452.],
#         [517., 450.]]], dtype=float32),) [[1]]
# (array([[[528., 386.],
#         [575., 390.],
#         [564., 447.],
#         [515., 443.]]], dtype=float32),) [[1]]
# (array([[[528., 381.],
#         [576., 388.],
#         [563., 444.],
#         [516., 439.]]], dtype=float32),) [[1]]
# (array([[[528., 377.],
#         [577., 387.],
#         [564., 442.],
#         [514., 434.]]], dtype=float32),) [[1]]
# (array([[[531., 375.],
#         [581., 387.],
#         [566., 442.],
#         [516., 432.]]], dtype=float32),) [[1]]
# (array([[[534., 375.],
#         [584., 387.],
#         [569., 442.],
#         [519., 431.]]], dtype=float32),) [[1]]
# (array([[[537., 375.],
#         [587., 387.],
#         [573., 441.],
#         [522., 430.]]], dtype=float32),) [[1]]
# (array([[[541., 374.],
#         [591., 387.],
#         [576., 441.],
#         [525., 429.]]], dtype=float32),) [[1]]
# (array([[[545., 374.],
#         [595., 387.],
#         [581., 440.],
#         [529., 429.]]], dtype=float32),) [[1]]
# (array([[[548., 374.],
#         [599., 387.],
#         [584., 441.],
#         [533., 429.]]], dtype=float32),) [[1]]
# (array([[[552., 375.],
#         [601., 387.],
#         [588., 441.],
#         [536., 430.]]], dtype=float32),) [[1]]
# (array([[[556., 376.],
#         [606., 389.],
#         [591., 443.],
#         [540., 431.]]], dtype=float32),) [[1]]
# (array([[[560., 378.],
#         [610., 390.],
#         [596., 444.],
#         [545., 433.]]], dtype=float32),) [[1]]
# (array([[[565., 380.],
#         [616., 392.],
#         [601., 446.],
#         [550., 434.]]], dtype=float32),) [[1]]
# (array([[[572., 381.],
#         [624., 394.],
#         [610., 448.],
#         [558., 436.]]], dtype=float32),) [[1]]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# (array([[[794., 420.],
#         [837., 432.],
#         [822., 486.],
#         [779., 477.]]], dtype=float32),) [[1]]
# (array([[[803., 423.],
#         [845., 435.],
#         [828., 489.],
#         [787., 479.]]], dtype=float32),) [[1]]
# (array([[[809., 425.],
#         [850., 437.],
#         [834., 492.],
#         [793., 482.]]], dtype=float32),) [[1]]
# (array([[[812., 428.],
#         [853., 440.],
#         [837., 495.],
#         [795., 484.]]], dtype=float32),) [[1]]
# (array([[[813., 431.],
#         [855., 443.],
#         [838., 498.],
#         [797., 488.]]], dtype=float32),) [[1]]
# (array([[[814., 433.],
#         [855., 445.],
#         [839., 500.],
#         [796., 490.]]], dtype=float32),) [[1]]
# (array([[[813., 436.],
#         [854., 447.],
#         [837., 503.],
#         [795., 493.]]], dtype=float32),) [[1]]
# (array([[[811., 439.],
#         [854., 450.],
#         [836., 505.],
#         [794., 496.]]], dtype=float32),) [[1]]
# (array([[[810., 441.],
#         [853., 452.],
#         [834., 508.],
#         [793., 498.]]], dtype=float32),) [[1]]
# (array([[[811., 442.],
#         [853., 453.],
#         [836., 509.],
#         [793., 500.]]], dtype=float32),) [[1]]
# (array([[[812., 443.],
#         [854., 454.],
#         [836., 510.],
#         [794., 501.]]], dtype=float32),) [[1]]
# (array([[[516., 403.],
#         [308., 453.],
#         [325., 248.],
#         [489., 224.]]], dtype=float32), array([[[818., 445.],
#         [856., 454.],
#         [839., 510.],
#         [801., 503.]]], dtype=float32)) [[91]
#  [ 1]]
# markers detected so far are : [1, 74, 17, 91]
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
# () None
